# %% [markdown]
# ## My model

# %%
from pgmpy.models import BayesianNetwork
from pgmpy.factors.discrete import TabularCPD

# %%
# Defining the network structure
model = BayesianNetwork([("debtsToIncomeRatio", "creditWorthiness"), ("reliability", "creditWorthiness")])

# %%
# Defining the CPDs:
cpd_dti = TabularCPD("debtsToIncomeRatio", 2, [[0.3], [0.7]])
cpd_r = TabularCPD("reliability", 2, [[0.6664], [0.3336]])
cpd_cw = TabularCPD(
    "creditWorthiness",
    2,
    [
        [0.2, 0.3, 0.4, 0.5],
        [0.8, 0.7, 0.6, 0.5],
    ],
    evidence=["debtsToIncomeRatio", "reliability"],
    evidence_card=[2, 2],
)

# %%
# Associating the CPDs with the network structure.
model.add_cpds(cpd_dti, cpd_r, cpd_cw)

# %%
# Checking the model for various errors
model.check_model()
# Out:
# True

# %%
model.simulate()
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
#    creditWorthiness  debtsToIncomeRatio  reliability
# 0                 1                   1            1
# 1                 1                   0            0
# 2                 0                   0            0
# 3                 1                   1            0
# 4                 0                   1            1
# 5                 1                   0            1
# 6                 1                   0            1
# 7                 1                   1            1
# 8                 1                   0            1
# 9                 1                   0            1

# %% [markdown]
# ## Example from docs

# %%
from pgmpy.utils import get_example_model

# %%
model = get_example_model('alarm')

# %%
model.simulate(n_samples=10)
# Out:
#   0%|          | 0/37 [00:00<?, ?it/s]
#   HRSAT CATECHOL PULMEMBOLUS     CVP   HREKG      HR  ARTCO2 LVFAILURE  \
# 0  HIGH     HIGH       FALSE     LOW    HIGH    HIGH    HIGH     FALSE
# 1  HIGH     HIGH       FALSE  NORMAL    HIGH    HIGH    HIGH     FALSE
# 2  HIGH     HIGH       FALSE  NORMAL    HIGH    HIGH    HIGH     FALSE
# 3  HIGH     HIGH       FALSE  NORMAL    HIGH    HIGH    HIGH     FALSE
# 4   LOW   NORMAL       FALSE  NORMAL     LOW  NORMAL  NORMAL     FALSE
# 5  HIGH     HIGH       FALSE  NORMAL    HIGH    HIGH    HIGH     FALSE
# 6  HIGH     HIGH       FALSE  NORMAL    HIGH    HIGH     LOW     FALSE
# 7  HIGH     HIGH       FALSE    HIGH    HIGH    HIGH    HIGH     FALSE
# 8  HIGH     HIGH       FALSE  NORMAL    HIGH    HIGH    HIGH     FALSE
# 9   LOW     HIGH       FALSE     LOW  NORMAL     LOW    HIGH     FALSE
#
#   HISTORY VENTLUNG  ... VENTTUBE    FIO2      BP     TPR LVEDVOLUME EXPCO2  \
# 0   FALSE     ZERO  ...      LOW  NORMAL     LOW     LOW     NORMAL    LOW
# 1   FALSE     ZERO  ...     ZERO  NORMAL  NORMAL    HIGH     NORMAL    LOW
# 2   FALSE     ZERO  ...      LOW  NORMAL     LOW     LOW     NORMAL    LOW
# 3   FALSE     ZERO  ...      LOW  NORMAL     LOW     LOW     NORMAL    LOW
# 4   FALSE     ZERO  ...      LOW  NORMAL    HIGH    HIGH     NORMAL    LOW
# 5   FALSE     ZERO  ...      LOW  NORMAL     LOW     LOW     NORMAL    LOW
# 6   FALSE      LOW  ...     ZERO  NORMAL    HIGH  NORMAL     NORMAL    LOW
# 7   FALSE     ZERO  ...      LOW  NORMAL    HIGH  NORMAL       HIGH    LOW
# 8   FALSE     ZERO  ...      LOW  NORMAL    HIGH  NORMAL     NORMAL    LOW
# 9   FALSE     ZERO  ...      LOW  NORMAL  NORMAL    HIGH        LOW    LOW
#
#     PRESS SAO2  HRBP     PAP
# 0  NORMAL  LOW  HIGH    HIGH
# 1     LOW  LOW  HIGH  NORMAL
# 2    HIGH  LOW  HIGH  NORMAL
# 3     LOW  LOW  HIGH    HIGH
# 4  NORMAL  LOW   LOW  NORMAL
# 5    HIGH  LOW  HIGH  NORMAL
# 6    HIGH  LOW  HIGH  NORMAL
# 7    HIGH  LOW  HIGH  NORMAL
# 8    HIGH  LOW  HIGH  NORMAL
# 9  NORMAL  LOW   LOW    HIGH
#
# [10 rows x 37 columns]

# %%
model.simulate(n_samples=20, evidence={"HRSAT": "HIGH"})
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
#    HRSAT CATECHOL PULMEMBOLUS     CVP HREKG      HR  ARTCO2 LVFAILURE HISTORY  \
# 0   HIGH   NORMAL       FALSE  NORMAL   LOW  NORMAL  NORMAL     FALSE   FALSE
# 1   HIGH     HIGH       FALSE  NORMAL  HIGH    HIGH    HIGH     FALSE   FALSE
# 2   HIGH     HIGH       FALSE  NORMAL  HIGH    HIGH    HIGH     FALSE   FALSE
# 3   HIGH     HIGH       FALSE  NORMAL  HIGH    HIGH    HIGH     FALSE   FALSE
# 4   HIGH     HIGH        TRUE  NORMAL  HIGH    HIGH    HIGH     FALSE   FALSE
# 5   HIGH     HIGH       FALSE  NORMAL  HIGH    HIGH    HIGH     FALSE   FALSE
# 6   HIGH     HIGH       FALSE    HIGH  HIGH    HIGH    HIGH     FALSE    TRUE
# 7   HIGH     HIGH       FALSE  NORMAL  HIGH    HIGH    HIGH     FALSE   FALSE
# 8   HIGH     HIGH       FALSE  NORMAL  HIGH    HIGH    HIGH     FALSE   FALSE
# 9   HIGH     HIGH       FALSE  NORMAL  HIGH    HIGH    HIGH     FALSE   FALSE
# 10  HIGH     HIGH       FALSE  NORMAL  HIGH    HIGH    HIGH     FALSE   FALSE
# 11  HIGH     HIGH        TRUE  NORMAL  HIGH    HIGH    HIGH     FALSE   FALSE
# 12  HIGH     HIGH       FALSE  NORMAL  HIGH    HIGH    HIGH     FALSE   FALSE
# 13  HIGH     HIGH       FALSE     LOW  HIGH    HIGH     LOW     FALSE   FALSE
# 14  HIGH     HIGH       FALSE     LOW  HIGH    HIGH     LOW     FALSE   FALSE
# 15  HIGH     HIGH        TRUE    HIGH  HIGH    HIGH     LOW     FALSE   FALSE
# 16  HIGH     HIGH       FALSE  NORMAL  HIGH    HIGH    HIGH     FALSE   FALSE
# 17  HIGH     HIGH       FALSE    HIGH  HIGH    HIGH    HIGH     FALSE   FALSE
# 18  HIGH     HIGH       FALSE    HIGH  HIGH    HIGH    HIGH     FALSE   FALSE
# 19  HIGH     HIGH       FALSE  NORMAL  HIGH    HIGH     LOW     FALSE   FALSE
#
#    VENTLUNG  ... VENTTUBE    FIO2      BP     TPR LVEDVOLUME  EXPCO2   PRESS  \
# 0      ZERO  ...     ZERO  NORMAL  NORMAL    HIGH     NORMAL     LOW     LOW
# 1      ZERO  ...      LOW     LOW    HIGH    HIGH     NORMAL     LOW    HIGH
# 2      ZERO  ...      LOW  NORMAL    HIGH  NORMAL     NORMAL     LOW     LOW
# 3      ZERO  ...      LOW  NORMAL    HIGH  NORMAL     NORMAL     LOW  NORMAL
# 4      ZERO  ...      LOW  NORMAL    HIGH    HIGH     NORMAL     LOW     LOW
# 5      ZERO  ...      LOW  NORMAL    HIGH    HIGH     NORMAL     LOW     LOW
# 6      ZERO  ...      LOW  NORMAL    HIGH    HIGH     NORMAL     LOW    HIGH
# 7      ZERO  ...      LOW  NORMAL    HIGH    HIGH     NORMAL     LOW  NORMAL
# 8      ZERO  ...      LOW  NORMAL    HIGH    HIGH     NORMAL     LOW  NORMAL
# 9      ZERO  ...     ZERO  NORMAL    HIGH  NORMAL     NORMAL     LOW    HIGH
# 10     ZERO  ...      LOW  NORMAL    HIGH  NORMAL     NORMAL     LOW    HIGH
# 11     ZERO  ...     ZERO  NORMAL    HIGH    HIGH     NORMAL     LOW    HIGH
# 12      LOW  ...      LOW  NORMAL    HIGH    HIGH     NORMAL  NORMAL    HIGH
# 13      LOW  ...     HIGH  NORMAL    HIGH  NORMAL        LOW     LOW     LOW
# 14   NORMAL  ...     HIGH  NORMAL     LOW     LOW        LOW  NORMAL    HIGH
# 15      LOW  ...     ZERO  NORMAL     LOW     LOW       HIGH     LOW    HIGH
# 16     ZERO  ...      LOW  NORMAL     LOW     LOW     NORMAL     LOW    HIGH
# 17     ZERO  ...      LOW  NORMAL     LOW     LOW       HIGH     LOW  NORMAL
# 18     ZERO  ...      LOW  NORMAL     LOW    HIGH       HIGH     LOW     LOW
# 19      LOW  ...     HIGH  NORMAL     LOW     LOW     NORMAL     LOW     LOW
#
#       SAO2    HRBP     PAP
# 0      LOW     LOW  NORMAL
# 1      LOW    HIGH    HIGH
# 2      LOW    HIGH  NORMAL
# 3      LOW    HIGH  NORMAL
# 4      LOW    HIGH    HIGH
# 5      LOW  NORMAL  NORMAL
# 6      LOW    HIGH  NORMAL
# 7      LOW    HIGH  NORMAL
# 8      LOW    HIGH  NORMAL
# 9      LOW    HIGH  NORMAL
# 10     LOW    HIGH    HIGH
# 11     LOW    HIGH    HIGH
# 12     LOW    HIGH  NORMAL
# 13    HIGH    HIGH  NORMAL
# 14    HIGH    HIGH  NORMAL
# 15  NORMAL    HIGH    HIGH
# 16     LOW    HIGH  NORMAL
# 17     LOW    HIGH  NORMAL
# 18     LOW    HIGH  NORMAL
# 19    HIGH    HIGH  NORMAL
#
# [20 rows x 37 columns]
